# %%
import requests
from bs4 import BeautifulSoup
url ='http://books.toscrape.com/catalogue/category/books/mystery_3/index.html'
response=requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')

# %%
all_a=soup.find_all('a')

# %%
all_a
# Out:
# [<a href="../../../../index.html">Books to Scrape</a>,
#  <a href="../../../../index.html">Home</a>,
#  <a href="../../books_1/index.html">Books</a>,
#  <a href="../../books_1/index.html">
#
#                                  Books
#
#                          </a>,
#  <a href="../travel_2/index.html">
#
#                                  Travel
#
#                          </a>,
#  <a href="index.html">
#  <strong>Mystery</strong>
#  </a>,
#  <a href="../historical-fiction_4/index.html">
#
#                                  Historical Fiction
#
#                          </a>,
#  <a href="../sequential-art_5/index.html">
#
#                                  Sequential Art
#
#                          </a>,
#  <a href="../classics_6/index.html">
#
#                                  Classics
#
#                          </a>,
#  <a href="../philosophy_7/index.html">
#
#                                  Philosophy
#
#                          </a>,
# ...

# %%
    category=all_a[0].get("href")

# %%
all_a.('href')
# Out:
#   File "C:\Users\hanab\AppData\Local\Temp/ipykernel_24036/1341359021.py", line 1
#     all_a.('href')
#           ^
# SyntaxError: invalid syntax

# %%
all_a[0].get_text().strip()
# Out:
# 'Books to Scrape'

# %%
all_a=soup.find_all('a')
catgindex=0
for i in range (0,len(all_a)):
        
    if(((all_a[i]).get_text().strip())!='Travel'):
        
        catgindex+=1
        
    else:
        break
        
all_a=all_a[catgindex:]

# %%
catgindex
# Out:
# 4

# %%
all_a
# Out:
# [<a href="../travel_2/index.html">
#
#                                  Travel
#
#                          </a>,
#  <a href="index.html">
#  <strong>Mystery</strong>
#  </a>,
#  <a href="../historical-fiction_4/index.html">
#
#                                  Historical Fiction
#
#                          </a>,
#  <a href="../sequential-art_5/index.html">
#
#                                  Sequential Art
#
#                          </a>,
#  <a href="../classics_6/index.html">
#
#                                  Classics
#
#                          </a>,
#  <a href="../philosophy_7/index.html">
#
#                                  Philosophy
#
#                          </a>,
#  <a href="../romance_8/index.html">
#
#                                  Romance
#
#                          </a>,
#  <a href="../womens-fiction_9/index.html">
#
#                                  Womens Fiction
#
#                          </a>,
#  <a href="../fiction_10/index.html">
#
# ...

# %%
categories=[]
for i in all_a:
    categories.append((i.get_text().strip()))

# %%
categories
# Out:
# ['Travel',
#  'Mystery',
#  'Historical Fiction',
#  'Sequential Art',
#  'Classics',
#  'Philosophy',
#  'Romance',
#  'Womens Fiction',
#  'Fiction',
#  'Childrens',
#  'Religion',
#  'Nonfiction',
#  'Music',
#  'Default',
#  'Science Fiction',
#  'Sports and Games',
#  'Add a comment',
#  'Fantasy',
#  'New Adult',
#  'Young Adult',
#  'Science',
#  'Poetry',
#  'Paranormal',
#  'Art',
#  'Psychology',
#  'Autobiography',
#  'Parenting',
#  'Adult Fiction',
#  'Humor',
#  'Horror',
#  'History',
#  'Food and Drink',
#  'Christian Fiction',
#  'Business',
#  'Biography',
#  'Thriller',
#  'Contemporary',
#  'Spirituality',
#  'Academic',
#  'Self Help',
#  'Historical',
#  'Christian',
#  'Suspense',
#  'Short Stories',
#  'Novels',
#  'Health',
#  'Politics',
#  'Cultural',
#  'Erotica',
#  'Crime',
#  '',
#  'Sharp Objects',
#  '',
#  'In a Dark, Dark ...',
#  '',
#  'The Past Never Ends',
#  '',
#  'A Murder in Time',
#  '',
#  'The Murder of Roger ...',
#  '',
# ...

# %%
d=categories.index("Crime")

# %%
categories=categories[:d+1]

# %%
categories
# Out:
# ['Travel',
#  'Mystery',
#  'Historical Fiction',
#  'Sequential Art',
#  'Classics',
#  'Philosophy',
#  'Romance',
#  'Womens Fiction',
#  'Fiction',
#  'Childrens',
#  'Religion',
#  'Nonfiction',
#  'Music',
#  'Default',
#  'Science Fiction',
#  'Sports and Games',
#  'Add a comment',
#  'Fantasy',
#  'New Adult',
#  'Young Adult',
#  'Science',
#  'Poetry',
#  'Paranormal',
#  'Art',
#  'Psychology',
#  'Autobiography',
#  'Parenting',
#  'Adult Fiction',
#  'Humor',
#  'Horror',
#  'History',
#  'Food and Drink',
#  'Christian Fiction',
#  'Business',
#  'Biography',
#  'Thriller',
#  'Contemporary',
#  'Spirituality',
#  'Academic',
#  'Self Help',
#  'Historical',
#  'Christian',
#  'Suspense',
#  'Short Stories',
#  'Novels',
#  'Health',
#  'Politics',
#  'Cultural',
#  'Erotica',
#  'Crime']

# %%
books = soup.find_all('article', attrs={'class':'product_pod'})
books
# Out:
# [<article class="product_pod">
#  <div class="image_container">
#  <a href="../../../sharp-objects_997/index.html"><img alt="Sharp Objects" class="thumbnail" src="../../../../media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg"/></a>
#  </div>
#  <p class="star-rating Four">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../sharp-objects_997/index.html" title="Sharp Objects">Sharp Objects</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£47.82</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
# ...

# %%
import requests
from bs4 import BeautifulSoup
home='https://books.toscrape.com/index.html'
response=requests.get(home)
soup2= BeautifulSoup(response.text,'html.parser')

# %%
soup2
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
links=soup2.find_all('a')
links
# Out:
# [<a href="index.html">Books to Scrape</a>,
#  <a href="index.html">Home</a>,
#  <a href="catalogue/category/books_1/index.html">
#
#                                  Books
#
#                          </a>,
#  <a href="catalogue/category/books/travel_2/index.html">
#
#                                  Travel
#
#                          </a>,
#  <a href="catalogue/category/books/mystery_3/index.html">
#
#                                  Mystery
#
#                          </a>,
#  <a href="catalogue/category/books/historical-fiction_4/index.html">
#
#                                  Historical Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/sequential-art_5/index.html">
#
#                                  Sequential Art
#
#                          </a>,
#  <a href="catalogue/category/books/classics_6/index.html">
#
#                                  Classics
#
#                          </a>,
# ...

# %%
urls=[]
for i in links:
    for j in categories:
        if i.get_text().strip()==j:
            urls.append(i.get("href"))

# %%
urls
# Out:
# ['catalogue/category/books/travel_2/index.html',
#  'catalogue/category/books/mystery_3/index.html',
#  'catalogue/category/books/historical-fiction_4/index.html',
#  'catalogue/category/books/sequential-art_5/index.html',
#  'catalogue/category/books/classics_6/index.html',
#  'catalogue/category/books/philosophy_7/index.html',
#  'catalogue/category/books/romance_8/index.html',
#  'catalogue/category/books/womens-fiction_9/index.html',
#  'catalogue/category/books/fiction_10/index.html',
#  'catalogue/category/books/childrens_11/index.html',
#  'catalogue/category/books/religion_12/index.html',
#  'catalogue/category/books/nonfiction_13/index.html',
#  'catalogue/category/books/music_14/index.html',
#  'catalogue/category/books/default_15/index.html',
#  'catalogue/category/books/science-fiction_16/index.html',
#  'catalogue/category/books/sports-and-games_17/index.html',
#  'catalogue/category/books/add-a-comment_18/index.html',
# ...

# %%
import requests
from bs4 import BeautifulSoup
all_Titles=[]
for url in urls:
   
    response=requests.get( "http://"+url)
    soup = BeautifulSoup(response.text,'html.parser')
    books = soup.find_all('article') 
    titles = []

    for book in books:
        title = book.find('h3').find('a').attrs['title']
        titles.append(title)
        all_Titles.append(titles)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Documents\Python Scripts\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\Documents\Python Scripts\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~\Documents\Python Scripts\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# ...

# %%
urls_http=["http://"+str(url)for url in urls]
urls_http
# Out:
# ['http://catalogue/category/books/travel_2/index.html',
#  'http://catalogue/category/books/mystery_3/index.html',
#  'http://catalogue/category/books/historical-fiction_4/index.html',
#  'http://catalogue/category/books/sequential-art_5/index.html',
#  'http://catalogue/category/books/classics_6/index.html',
#  'http://catalogue/category/books/philosophy_7/index.html',
#  'http://catalogue/category/books/romance_8/index.html',
#  'http://catalogue/category/books/womens-fiction_9/index.html',
#  'http://catalogue/category/books/fiction_10/index.html',
#  'http://catalogue/category/books/childrens_11/index.html',
#  'http://catalogue/category/books/religion_12/index.html',
#  'http://catalogue/category/books/nonfiction_13/index.html',
#  'http://catalogue/category/books/music_14/index.html',
#  'http://catalogue/category/books/default_15/index.html',
#  'http://catalogue/category/books/science-fiction_16/index.html',
# ...

# %%
import requests
from bs4 import BeautifulSoup
ALL_Categtitles = []
for url in urls_http:
   
    response=requests.request('GET' ,url)
    soup2 = BeautifulSoup(response.text,'html.parser')
    books = soup2.find_all('article') 
  
    titles=[]
    for book in books:
        title = book.find('h3').find('a').attrs['title']
        titles.append(title)
        ALL_Categtitles.append(titles)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Documents\Python Scripts\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\Documents\Python Scripts\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~\Documents\Python Scripts\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# ...

# %%
books = soup.find_all.find('article') 

titles = []

for book in books:
    title = book.find('h3').find('a').attrs['title']
    titles.append(title)

# %%
import requests
from bs4 import BeautifulSoup

url ='https://books.toscrape.com/index.html'
response=requests.get(url)
soup2 = BeautifulSoup(response.text,'html.parser')
                        
soup2
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
books = soup2.find_all('article') 

titles = []

for book in books:
    title = book.find('h3').find('a').attrs['title']
    titles.append(title)

# %%
titles
# Out:
# ['A Light in the Attic',
#  'Tipping the Velvet',
#  'Soumission',
#  'Sharp Objects',
#  'Sapiens: A Brief History of Humankind',
#  'The Requiem Red',
#  'The Dirty Little Secrets of Getting Your Dream Job',
#  'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#  'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#  'The Black Maria',
#  'Starving Hearts (Triangular Trade Trilogy, #1)',
#  "Shakespeare's Sonnets",
#  'Set Me Free',
#  "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#  'Rip it Up and Start Again',
#  'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#  'Olio',
#  'Mesaerion: The Best Science Fiction Stories 1800-1849',
#  'Libertarianism for Beginners',
#  "It's Only the Himalayas"]

# %%
type(soup2)
# Out:
# bs4.BeautifulSoup

# %%
list(soup2)
# Out:
# ['html',
#  '\n',
#  '[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]',
#  '\n',
#  '[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]',
#  '\n',
#  '[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]',
#  '\n',
#  '[if gt IE 8]><!',
#  ' ',
#  <html class="no-js" lang="en-us"> <!--<![endif]-->
#  <head>
#  <title>
#      All products | Books to Scrape - Sandbox
#  </title>
#  <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#  <meta content="24th Jun 2016 09:29" name="created"/>
#  <meta content="" name="description"/>
#  <meta content="width=device-width" name="viewport"/>
#  <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#  <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#  <!--[if lt IE 9]>
#          <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#          <![endif]-->
#  <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup
urls_http=["http://"+str(url)for url in urls]
for i in range(0,len(urls_http)):
    response=requests.get(urls_http[i])
    soup2 = BeautifulSoup(response.text,'html.parser')
    books = soup.find_all('article')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Documents\Python Scripts\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\Documents\Python Scripts\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~\Documents\Python Scripts\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# ...

# %%
soup2
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup
titles=[]
prices=[]
stars=[]
rates = {'One':1, 'Two':2, 'Three':3, 'Four':4, 'Five':5}
for url in urls_http:
   
    response=requests.get(url)
    soup2 = BeautifulSoup(response.text,'html.parser')
   

    for book in books:
        title = book.find('h3').find('a').attrs['title']
        titles.append(title)
        product_price = book.find('div', attrs={'class':'product_price'})
        price = product_price.find('p', attrs={'class':'price_color'}).get_text()
        price = float(price[2:])
        prices.append(price)
        rating = book.find('p').get('class')[1]
        stars.append(rates[rating])
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Documents\Python Scripts\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\Documents\Python Scripts\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~\Documents\Python Scripts\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# ...

# %%
urls_http[0]
# Out:
# 'http://catalogue/category/books/travel_2/index.html'

# %%
urls[0]
# Out:
# 'catalogue/category/books/travel_2/index.html'

# %%
import csv

with open("books.csv", 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['Title', 'Price', 'Rating','category'])
    writer.writeheader()
    
    for title, price, rating in zip(titles, prices, stars,categories):
        writer.writerow({'Title':title, 'Price':price, 'Rating':rating ,'category':categories})
